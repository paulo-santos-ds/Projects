# %% [markdown]
# <a href="https://colab.research.google.com/github/paulo-santos-ds/Projects/blob/main/Ibovespa_VS_CDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Dados históricos da ação
ticker = yf.Ticker("^VIX")
data = ticker.history(period="10y")

# %%
# Obter dados históricos do CDI
ticker = yf.Ticker("^BVSP")
data = ticker.history(period="10y")

# %%
# Gráfico de linhas comparando do indice com o CDI
fig, ax1 = plt.subplots()

ax1.plot(data.index, data['Close'], color='tab:blue')
ax1.set_ylabel('Preço da ^VIX', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()

ax2.plot(cdi.index, cdi['valor'], color='tab:red')
ax2.set_ylabel('^BVSP', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title("Comparação do preço dO VIX VS CDI ")
plt.xlabel("Data")
plt.show()
